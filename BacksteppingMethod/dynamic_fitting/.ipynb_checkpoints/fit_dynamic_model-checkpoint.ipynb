# %%
import pandas as pd
import glob
import numpy as np
import matplotlib.pyplot as plt
import ast

# %%
# 设置文件夹路径
folder_path = "./data/train_sets"

# 使用glob获取所有csv文件路径
csv_files = glob.glob(folder_path + "/*.csv")

# %%
df = pd.read_csv(csv_files[4], header=None, names=['timestamp', 'state', 'head_x', 'head_y', 'tail_x', 'tail_y'])
df.head(-5)
# Out:
#           timestamp                                              state  \
# 0      1.727422e+09  [-0.9616016841488898, 1.2520974598961507, 0, 0...
# 1      1.727422e+09  [-0.9939072394582089, 1.2846847469928138, 0, 0...
# 2      1.727422e+09  [-0.9939072394582089, 1.2846847469928138, 0, 0...
# 3      1.727422e+09  [-0.9611345210281332, 1.252193760350082, 0, 0,...
# 4      1.727422e+09  [-0.9611345210281332, 1.252193760350082, 0, 0,...
# ...             ...                                                ...
# 10713  1.727423e+09       [0.0, 0.0, 0, 0, 0.0, 14.668172728477167, 0]
# 10714  1.727423e+09       [0.0, 0.0, 0, 0, 0.0, 14.666094940343475, 0]
# 10715  1.727423e+09       [0.0, 0.0, 0, 0, 0.0, 14.666094940343475, 0]
# 10716  1.727423e+09       [0.0, 0.0, 0, 0, 0.0, 14.689111750474726, 0]
# 10717  1.727423e+09       [0.0, 0.0, 0, 0, 0.0, 14.706517523976128, 0]
#
#        head_x  head_y  tail_x  tail_y
# 0         223     348     226     307
# 1         223     348     226     307
# 2         223     348     225     307
# 3         223     348     225     307
# 4         223     349     225     307
# ...       ...     ...     ...     ...
# 10713     332     399     337     438
# 10714     332     398     337     437
# 10715     332     397     337     436
# 10716     333     397     338     436
# 10717     334     396     338     435
#
# [10718 rows x 6 columns]

# %%
# 计算速度矢量
dt = np.diff(df['timestamp'].values)  # 时间间隔
dx = np.diff(x)  # x坐标的变化
dy = np.diff(y)  # y坐标的变化

# 速度分量
vx = dx / dt
vy = dy / dt

# 绘制轨迹图
plt.figure(figsize=(8, 6))
plt.plot(x, y, marker='o', linestyle='-', color='b', label='Robot Trajectory')

# 绘制速度箭头（使用quiver）
# `x[:-1]`, `y[:-1]` 是箭头的起点
# `vx`, `vy` 是箭头的方向和大小
plt.quiver(x[:-1], y[:-1], vx, vy, angles='xy', scale_units='xy', scale=1, color='r', width=0.002)

# 添加标题和标签
plt.title('Robot Movement Trajectory with Speed Vectors')
plt.xlabel('X Position')
plt.ylabel('Y Position')

# 显示图例
plt.legend()

# 显示图形
plt.grid(True)
plt.show()

# %%
# 2. 定义计算函数（包括速度、角速度、加速度）
def compute_velocity_and_yaw_from_df(row, df):
    head_x, head_y = row['head_x'], row['head_y']
    tail_x, tail_y = row['tail_x'], row['tail_y']
    
    # 获取当前和上一时刻的 timestamp
    timestamp = row['timestamp']
    prev_timestamp = df.iloc[row.name - 1]['timestamp'] if row.name > 0 else timestamp
    
    # 计算时间差（时间步长）
    dt = timestamp - prev_timestamp

    prev_head_x = row['head_x'] if row.name == 0 else df.iloc[row.name - 1]['head_x']
    prev_head_y = row['head_y'] if row.name == 0 else df.iloc[row.name - 1]['head_y']
    prev_tail_x = row['tail_x'] if row.name == 0 else df.iloc[row.name - 1]['tail_x']
    prev_tail_y = row['tail_y'] if row.name == 0 else df.iloc[row.name - 1]['tail_y']

    # 计算当前时刻与前一时刻的位移向量（头部和尾部分别）
    dx_head = head_x - prev_head_x
    dy_head = head_y - prev_head_y
    dx_tail = tail_x - prev_tail_x
    dy_tail = tail_y - prev_tail_y

    # 计算头部和尾部的位移向量
    displacement_head = np.array([dx_head, dy_head])
    displacement_tail = np.array([dx_tail, dy_tail])

    # 计算头部和尾部的偏航角（单位为弧度）
    yaw_head = np.arctan2(dy_head, dx_head)
    yaw_tail = np.arctan2(dy_tail, dx_tail)

    # 计算前进速度（沿着前进方向的速度）
    forward_velocity_head = np.linalg.norm(displacement_head) / dt if dt != 0 else 0
    forward_velocity_tail = np.linalg.norm(displacement_tail) / dt if dt != 0 else 0

    # 计算横向速度
    lateral_velocity_head = np.linalg.norm(displacement_head) * np.sin(yaw_head)
    lateral_velocity_tail = np.linalg.norm(displacement_tail) * np.sin(yaw_tail)

    lateral_velocity = (lateral_velocity_head + lateral_velocity_tail) / 2

    # 偏航角使用头部的偏航角
    yaw = yaw_head

    # 计算前进速度的平均值
    forward_velocity = (forward_velocity_head + forward_velocity_tail) / 2

    # 计算角速度（偏航角的变化率）
    prev_yaw = yaw_head if row.name == 0 else np.arctan2(df.iloc[row.name - 1]['head_y'] - df.iloc[row.name - 1]['tail_y'],
                                                       df.iloc[row.name - 1]['head_x'] - df.iloc[row.name - 1]['tail_x'])
    angular_velocity = (yaw_head - prev_yaw) / dt if dt != 0 else 0

    # 计算角加速度（角速度的变化率）
    prev_angular_velocity = angular_velocity if row.name == 0 else (np.arctan2(df.iloc[row.name - 1]['head_y'] - df.iloc[row.name - 1]['tail_y'],
                                                                           df.iloc[row.name - 1]['head_x'] - df.iloc[row.name - 1]['tail_x']) - prev_yaw) / dt
    angular_acceleration = (angular_velocity - prev_angular_velocity) / dt if dt != 0 else 0.0

    # 计算前进速度加速度（前进速度的变化率）
    prev_forward_velocity = forward_velocity_head if row.name == 0 else (np.linalg.norm(np.array([df.iloc[row.name - 1]['head_x'] - df.iloc[row.name - 1]['tail_x'],
                                                                               df.iloc[row.name - 1]['head_y'] - df.iloc[row.name - 1]['tail_y']])) / dt)
    forward_acceleration = (forward_velocity - prev_forward_velocity) / dt if dt != 0 else 0.0

    # 计算横向速度加速度（横向速度的变化率）
    prev_lateral_velocity = lateral_velocity_head if row.name == 0 else (np.linalg.norm(np.array([df.iloc[row.name - 1]['head_x'] - df.iloc[row.name - 1]['tail_x'],
                                                                                         df.iloc[row.name - 1]['head_y'] - df.iloc[row.name - 1]['tail_y']])) * np.sin(prev_yaw))
    lateral_acceleration = (lateral_velocity - prev_lateral_velocity) / dt if dt != 0 else 0.0

    return yaw, forward_velocity, lateral_velocity, angular_velocity, angular_acceleration, forward_acceleration, lateral_acceleration

# %%
# 计算每一行的数据
df['yaw'], df['forward_velocity'], df['lateral_velocity'], df['angular_velocity'], df['angular_acceleration'], df['forward_acceleration'], df['lateral_acceleration'] = zip(*df.apply(compute_velocity_and_yaw_from_df, axis=1, df=df))

# 输出结果
print(df)

# 过滤掉速度小于阈值的轨迹点
df_filtered = df[df['forward_velocity'] > velocity_threshold]

# 输出结果
print(df_filtered[['timestamp', 'yaw', 'forward_velocity', 'lateral_velocity', 'angular_velocity', 'angular_acceleration', 'forward_acceleration', 'lateral_acceleration']])
# Out:
#           timestamp                                              state  \
# 0      1.727422e+09  [-0.9616016841488898, 1.2520974598961507, 0, 0...
# 1      1.727422e+09  [-0.9939072394582089, 1.2846847469928138, 0, 0...
# 2      1.727422e+09  [-0.9939072394582089, 1.2846847469928138, 0, 0...
# 3      1.727422e+09  [-0.9611345210281332, 1.252193760350082, 0, 0,...
# 4      1.727422e+09  [-0.9611345210281332, 1.252193760350082, 0, 0,...
# ...             ...                                                ...
# 10718  1.727423e+09       [0.0, 0.0, 0, 0, 0.0, 14.706517523976128, 0]
# 10719  1.727423e+09       [0.0, 0.0, 0, 0, 0.0, 14.470045895588498, 0]
# 10720  1.727423e+09       [0.0, 0.0, 0, 0, 0.0, 14.470045895588498, 0]
# 10721  1.727423e+09         [0.0, 0.0, 0, 0, 0.0, 14.6457223724756, 0]
# 10722  1.727423e+09         [0.0, 0.0, 0, 0, 0.0, 14.6457223724756, 0]
#
#        head_x  head_y  tail_x  tail_y       yaw  forward_velocity  \
# 0         223     348     226     307  0.000000          0.000000
# 1         223     348     226     307  0.000000          0.000000
# 2         223     348     225     307  0.000000          8.280498
# 3         223     348     225     307  0.000000          0.000000
# 4         223     349     225     307  1.570796          6.884644
# ...       ...     ...     ...     ...       ...               ...
# 10718     334     395     337     434 -1.570796         29.261510
# 10719     334     394     338     434 -1.570796         16.481149
# 10720     334     394     338     432  0.000000         17.475684
# 10721     334     393     338     432 -1.570796          7.954756
# 10722     334     393     338     432  0.000000          0.000000
#
#        lateral_velocity  angular_velocity  angular_acceleration  \
# 0          0.000000e+00          0.000000              0.000000
# 1          0.000000e+00        -29.127420           -516.113621
# 2          6.123234e-17        -27.223576           -450.849517
# 3          0.000000e+00        -31.064039           -595.833127
# 4          5.000000e-01         -0.671141             -9.241127
# ...                 ...               ...                   ...
# 10718     -1.000000e+00          2.477596             60.059476
# 10719     -5.000000e-01          1.265289             20.853415
# 10720     -1.000000e+00         29.192518            510.159230
# 10721     -5.000000e-01          1.668541             26.545669
# 10722      0.000000e+00         26.010488            404.389862
#
#        forward_acceleration  lateral_acceleration
# 0                  0.000000              0.000000
# 1             -12907.137917           -726.485843
# 2             -11137.858598           -679.000821
# 3             -15101.963200           -786.412819
# 4              -7687.770825           -557.656147
# ...                     ...                   ...
# 10718         -22328.366042            921.159093
# 10719         -10353.169401            634.524223
# 10720         -11971.509882            681.551682
# 10721          -9544.860621            596.606672
# 10722          -9476.336239            606.340212
#
# [10723 rows x 13 columns]
#           timestamp       yaw  forward_velocity  lateral_velocity  \
# 2      1.727422e+09  0.000000          8.280498      6.123234e-17
# 4      1.727422e+09  1.570796          6.884644      5.000000e-01
# 5      1.727422e+09  0.000000          9.406041      0.000000e+00
# 7      1.727422e+09 -1.570796          9.837425     -5.000000e-01
# 8      1.727422e+09  1.570796          8.467491      5.000000e-01
# ...             ...       ...               ...               ...
# 10717  1.727423e+09 -0.785398         14.753584     -1.000000e+00
# 10718  1.727423e+09 -1.570796         29.261510     -1.000000e+00
# 10719  1.727423e+09 -1.570796         16.481149     -5.000000e-01
# 10720  1.727423e+09  0.000000         17.475684     -1.000000e+00
# 10721  1.727423e+09 -1.570796          7.954756     -5.000000e-01
#
#        angular_velocity  angular_acceleration  forward_acceleration  \
# 2            -27.223576           -450.849517         -11137.858598
# 4             -0.671141             -9.241127          -7687.770825
# 5            -30.445085           -572.735416         -14703.460132
# 7            -63.213325          -1243.712627         -16106.059168
# 8             -1.236941            -20.947569         -11646.577155
# ...                 ...                   ...                   ...
# 10717         11.157804            136.373690          -5693.333011
# 10718          2.477596             60.059476         -22328.366042
# 10719          1.265289             20.853415         -10353.169401
# 10720         29.192518            510.159230         -11971.509882
# 10721          1.668541             26.545669          -9544.860621
#
#        lateral_acceleration
# 2               -679.000821
# 4               -557.656147
# 5               -790.107410
# 7               -836.181086
# 8               -685.866783
# ...                     ...
# 10717            464.446241
# 10718            921.159093
# 10719            634.524223
# 10720            681.551682
# 10721            596.606672
#
# [10637 rows x 8 columns]

# %%
import re

# 假设 df_filtered 是你的 DataFrame

# 定义一个函数来处理字符串并提取有效的浮点数
def convert_state_to_array(state_str):
    # 处理类似 'np.float64(0.8686709298331904)' 的情况，提取数值部分
    state_str = re.sub(r'np\.float64\((.*?)\)', r'\1', state_str)
    
    # 去掉两边的方括号
    state_str = state_str.strip('[]')
    
    # 按逗号分割字符串，得到一个列表的字符串
    state_list = state_str.split(', ')
    
    # 将列表中的字符串转换为浮点数
    state_float = [float(x) for x in state_list]
    
    # 返回浮点数列表
    return np.array(state_float)

# 使用 apply 方法将该函数应用到 'state' 列
df_filtered['state'] = df_filtered['state'].apply(convert_state_to_array)

# 打印转换后的 DataFrame 以检查
print(df_filtered.head())
# Out:
#       timestamp                                              state  head_x  \
# 2  1.727422e+09  [-0.9939072394582089, 1.2846847469928138, 0.0,...     223
# 4  1.727422e+09  [-0.9611345210281332, 1.252193760350082, 0.0, ...     223
# 5  1.727422e+09  [-0.9663337873019593, 1.256446787668815, 0.0, ...     223
# 7  1.727422e+09  [-0.9977471997476901, 1.2882523488896294, 0.0,...     223
# 8  1.727422e+09  [-0.9977471997476901, 1.2882523488896294, 0.0,...     223
#
#    head_y  tail_x  tail_y       yaw  forward_velocity  lateral_velocity  \
# 2     348     225     307  0.000000          8.280498      6.123234e-17
# 4     349     225     307  1.570796          6.884644      5.000000e-01
# 5     349     226     307  0.000000          9.406041      0.000000e+00
# 7     348     226     307 -1.570796          9.837425     -5.000000e-01
# 8     349     226     307  1.570796          8.467491      5.000000e-01
#
#    angular_velocity  angular_acceleration  forward_acceleration  \
# 2        -27.223576           -450.849517         -11137.858598
# 4         -0.671141             -9.241127          -7687.770825
# 5        -30.445085           -572.735416         -14703.460132
# 7        -63.213325          -1243.712627         -16106.059168
# 8         -1.236941            -20.947569         -11646.577155
#
#    lateral_acceleration  delta_forward_velocity  delta_lateral_velocity
# 2           -679.000821                     NaN                     NaN
# 4           -557.656147                1.395854                     0.5
# 5           -790.107410                2.521397                     0.5
# 7           -836.181086                0.431384                     0.5
# 8           -685.866783                1.369933                     1.0
# C:\Users\HP\AppData\Local\Temp\ipykernel_26912\2049863085.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['state'] = df_filtered['state'].apply(convert_state_to_array)

# %%
# 假设 df_filtered 是你的 DataFrame，并且已经有了 'state'、'forward_velocity' 和 'lateral_velocity' 列

# 设置速度变化的阈值
delta_v_threshold = 5.0  # 可以根据需求调整，这里假设 5 m/s 的变化超过了阈值

# 计算速度差值
df_filtered['delta_forward_velocity'] = df_filtered['forward_velocity'].diff().abs()
df_filtered['delta_lateral_velocity'] = df_filtered['lateral_velocity'].diff().abs()

# 过滤掉速度差值超过阈值的点
df_filtered_filtered = df_filtered[(df_filtered['delta_forward_velocity'] < delta_v_threshold) & 
                                    (df_filtered['delta_lateral_velocity'] < delta_v_threshold) &
                                     ]

# 画出控制状态中每个变量和速度的关系（关于时间）
plt.figure(figsize=(14, 10))

# 假设 state 中有多个变量，使用循环依次绘制每个状态变量和速度随时间的关系
num_state_variables = df_filtered_filtered['state'].iloc[0].shape[0]  # 获取状态向量的维度

# 绘制每个状态变量与时间的关系
for i in range(num_state_variables):
    # 画状态变量 vs 时间
    plt.subplot(num_state_variables, 2, 2*i + 1)
    plt.plot(df_filtered_filtered['timestamp'], df_filtered_filtered['state'].apply(lambda x: x[i]), marker='o', linestyle='-', color='b')
    plt.title(f'State variable {i+1} vs Time')
    plt.xlabel('Time (s)')
    plt.ylabel(f'State variable {i+1}')
    
    # 画前进速度 vs 时间
    plt.subplot(num_state_variables, 2, 2*i + 2)
    plt.plot(df_filtered_filtered['timestamp'], df_filtered_filtered['forward_velocity'], marker='o', linestyle='-', color='r')
    plt.title(f'Forward Velocity vs Time')
    plt.xlabel('Time (s)')
    plt.ylabel('Forward Velocity (m/s)')

# 自动调整布局，防止重叠
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_26912\1302035651.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['delta_forward_velocity'] = df_filtered['forward_velocity'].diff().abs()
# C:\Users\HP\AppData\Local\Temp\ipykernel_26912\1302035651.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['delta_lateral_velocity'] = df_filtered['lateral_velocity'].diff().abs()
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: -2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[92], line 13
#       8 df_filtered['delta_lateral_velocity'] = df_filtered['lateral_velocity'].diff().abs()
#      10 # 过滤掉速度差值超过阈值的点
#      11 df_filtered_filtered = df_filtered[(df_filtered['delta_forward_velocity'] < delta_v_threshold) &
#      12                                     (df_filtered['delta_lateral_velocity'] < delta_v_threshold) &
# ---> 13                                       (abs(df_filtered['state'][-2]) < 0.01)]
#      15 # 画出控制状态中每个变量和速度的关系（关于时间）
#      16 plt.figure(figsize=(14, 10))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: -2
